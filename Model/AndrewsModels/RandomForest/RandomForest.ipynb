# %%
#Final Model created using Random Forest Classifier

# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
import csv

# %%
#Training data with seasons 2002 - 2018 every game
train_data = pd.read_csv(r"C:\Users\comic\NFL-Predictor\Data\Train-Data\Compiled\testNOPERCENTAGES.csv")
train_data.head()
#Here is preview of first 5 games 
#Note if outcome is 1 that means team won the game
# Out:
#                     T1  T1 Outcome  T1 Score T1 Location  T1 Avg Points  \
# 0  San Francisco 49ers           1        16        Away        22.9375
# 1      Atlanta Falcons           0        34        Away        25.1250
# 2        Buffalo Bills           0        31        Home        23.6875
# 3   San Diego Chargers           1        34        Away        20.8125
# 4       Miami Dolphins           1        49        Home        23.6250
#
#    T1 Avg Yards  T1 NPY/A  T1 NRY/A  T1 3rd  T1 4th  ...  T2 NPY/A  T2 NRY/A  \
# 0      356.3125       5.8       4.6    0.52    0.62  ...       6.9       3.9
# 1      345.9375       6.1       4.5    0.42    0.60  ...       6.0       4.3
# 2      349.4375       6.0       4.1    0.43    0.58  ...       6.6       4.0
# 3      332.8125       5.7       4.6    0.37    0.33  ...       5.5       4.1
# 4      337.0000       6.0       4.7    0.38    0.30  ...       5.0       4.1
#
# ...

# %%
#Testing data with 2019 season
test_data = pd.read_csv(r"C:\Users\comic\NFL-Predictor\Data\Test-Data\Matchups\Matchup2019.csv")
test_data.head()
#Here is a preview of first 5 games 
#Note if outcome is 1 that means team won the game
# Out:
#                     T1  T1 Outcome  T1 Score T1 Location  T1 Avg Points  \
# 0        Chicago Bears           0         3        Home        17.5000
# 1     Tennessee Titans           1        43        Away        25.1250
# 2    Minnesota Vikings           1        28        Home        25.4375
# 3  Washington Redskins           0        27        Away        16.6250
# 4     Los Angeles Rams           1        30        Away        24.6250
#
#    T1 Avg Yards  T1 NPY/A  T1 NRY/A  T1 3rd  T1 4th  ...  T2 NPY/A  T2 NRY/A  \
# 0      296.8125       5.3       3.7   0.356   0.333  ...       6.1       4.4
# 1      362.8125       7.1       5.0   0.378   0.286  ...       6.1       4.8
# 2      353.5000       7.1       4.5   0.428   0.533  ...       6.4       3.8
# 3      274.6875       5.3       4.4   0.291   0.429  ...       5.9       4.3
# 4      374.8750       6.9       3.7   0.399   0.231  ...       5.3       4.7
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier


y = train_data["T1 Outcome"]#Want to train data on the first team's outcome column 


features = ["T1 Location", "T2 Location", "T1 Avg Points", "T2 Avg Points", "T1 Avg Yards","T2 Avg Yards", "T1 NPY/A", "T2 NPY/A", "T1 NRY/A", "T2 NRY/A", "T1 Avg Points Def", "T2 Avg Points Def", "T1 Avg Yards Def", "T2 Avg Yards Def", "T1 NPY/A Def", "T2 NPY/A Def","T1 NRY/A Def", "T2 NRY/A Def", "T1 4th Def", "T2 4th Def", "T1 3rd", "T2 3rd", "T1 4th", "T2 4th", "T1 3rd Def", "T2 3rd Def"]
#Here's the features I used to first achieve over 70% prediction accuracy 

x = pd.get_dummies(train_data[features])
x_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=1, min_samples_leaf=25,n_jobs=5, oob_score=True)#Subject to change these parameters, but these seem to work pretty well
model.fit(x, y)
predictions = model.predict(x_test)

output = pd.DataFrame({'T1': test_data.T1, 'T1 Outcome': predictions})
output.to_csv('FinalModel.csv', index=False)#Put model into a .csv file

# %%
prediction_model = pd.read_csv(r"C:\Users\comic\FinalModel.csv")
prediction_model.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 prediction_model = pd.read_csv(r"C:\Users\comic\FinalModel.csv")
#       2 prediction_model.head()
#
# ...

# %%
output = pd.DataFrame({'Team': prediction_model['T1'], 'Outcomes': predictions})
print(output)

# %%
import random

# %%
right = 0
wrong = 0

# %%
for i in range(len(prediction_model["T1"])):
    if test_data["T1 Outcome"][i] == prediction_model['T1 Outcome'][i]:
        right+=1
    else:
        wrong+=1

# %%
print(str((right/(right+wrong))*100)+"%")
# Out:
# 71.484375%

# %%
#Here's the percentage I get from the 2019 season, almost 71.5% accurate!
